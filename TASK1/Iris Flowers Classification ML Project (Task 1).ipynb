# %% [markdown]
# # LGM VIRTUAL INTERNSHIP PROGRAM 2022

# %% [markdown]
# # Task1

# %% [markdown]
# #### Done by:Bhuvan shetty

# %% [markdown]
# ![Screenshot%20%2866%29.png](attachment:Screenshot%20%2866%29.png)

# %% [markdown]
# ### dataset link:http://archive.ics.uci.edu/ml/datasets/Iris

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading the data

# %%
iris_data=pd.read_csv("iris.csv")

# %% [markdown]
# ### About data

# %%
iris_data.keys()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_data.head() #Top 5 values
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.tail() #last five values
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris_data.shape
# Out:
# (150, 6)

# %%
iris_data.describe() #Decribe the mathametical calculation about the data
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_data.isnull().sum() #sum of the missing values in each data columns
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Data representation-Visualization

# %%
#We use box plot to represent the out data
snb.boxplot(x="Species",y="SepalLengthCm",data=iris_data)
plt.show()

# %%
snb.boxplot(x="Species",y="SepalWidthCm",data=iris_data)
plt.show()

# %%
snb.boxplot(x="Species",y="PetalLengthCm",data=iris_data)
plt.show()

# %%
snb.boxplot(x="Species",y="PetalLengthCm",data=iris_data)
plt.show()

# %%
snb.pairplot(iris_data,hue="Species")
plt.show()

# %% [markdown]
# ### Data Preprocessing -Correlation Matrix

# %%
#() iris_data.corr() is used to find the pairwise correlation of all columns in the dataframe.
iris_data.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
#The figure() function in pyplot module of matplotlib library is used to create a new figure.
plt.figure(figsize=(10,8))
#Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
#annot: If True, write the data value in each cell.
snb.heatmap(iris_data.corr(),annot=True,cmap='seismic')
plt.show()

# %% [markdown]
# ### Label Encoder

# %% [markdown]
# #### Encode labels with value between 0 and n_classes-1.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
#fit_transform(y):Fit label encoder and return encoded labels(convert categorical value to discreate value)
iris_data['Species']=le.fit_transform(iris_data['Species'])

# %%
iris_data.head(),iris_data.tail()
# Out:
# (   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
#  0   1            5.1           3.5            1.4           0.2        0
#  1   2            4.9           3.0            1.4           0.2        0
#  2   3            4.7           3.2            1.3           0.2        0
#  3   4            4.6           3.1            1.5           0.2        0
#  4   5            5.0           3.6            1.4           0.2        0,
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
#  145  146            6.7           3.0            5.2           2.3        2
#  146  147            6.3           2.5            5.0           1.9        2
#  147  148            6.5           3.0            5.2           2.0        2
#  148  149            6.2           3.4            5.4           2.3        2
#  149  150            5.9           3.0            5.1           1.8        2)

# %%
X=iris_data.drop(columns=['Id','Species'])

# %%
y=iris_data['Species']

# %%
#random state-If you don't specify the random_state in your code,
#then every time you run(execute) your code a new random value 
#is generated and the train and test datasets would have different values each time.
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %% [markdown]
# ### Selecting Supervised ML Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
lr=LogisticRegression()
knn=KNeighborsClassifier()
dtc=DecisionTreeClassifier()
svc=SVC()
rfc=RandomForestClassifier()
gnb=GaussianNB()

# %% [markdown]
# ### Training, Testing, Evaluating Models

# %%
from sklearn.metrics import accuracy_score # For measuring the accuracy
models=[lr,knn,dtc,svc,rfc,gnb]
accu=[]
for model in models:
    model.fit(X_train,y_train) #Train different model
    y_predict=model.predict(X_test) #test our different model
    accu.append(accuracy_score(y_test,y_predict))
    print("Accuracy of ",type(model).__name__ ," model is", (accuracy_score(y_test,y_predict)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of  LogisticRegression  model is 0.9777777777777777
# Accuracy of  KNeighborsClassifier  model is 1.0
# Accuracy of  DecisionTreeClassifier  model is 0.9555555555555556
# Accuracy of  SVC  model is 0.9777777777777777
# Accuracy of  RandomForestClassifier  model is 0.9777777777777777
# Accuracy of  GaussianNB  model is 0.9777777777777777

# %%
results=pd.DataFrame({
    'Models':['Logistic Regression',
              'K-Nearest Neighbors',
              'Decision Tree',
              'Support Vector Machine',
              'Random Forest',
              'Gaussian Naive Bayes' ],
    'Accuracy':accu
                    })

# %%
results=results.sort_values(by='Accuracy',ascending=False)
print(results)
# Out:
#                    Models  Accuracy
# 1     K-Nearest Neighbors  1.000000
# 0     Logistic Regression  0.977778
# 3  Support Vector Machine  0.977778
# 4           Random Forest  0.977778
# 5    Gaussian Naive Bayes  0.977778
# 2           Decision Tree  0.955556

# %%
from sklearn.metrics import accuracy_score # For measuring the accuracy
models=[lr,knn,dtc,svc,rfc,gnb]
accu=[]
for model in models:
    model.fit(X_train,y_train) #Train different model
    y_predict=model.predict(X_test) #test our different model
    accu.append((accuracy_score(y_test,y_predict))*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# TO represent accuracy in percentage
results=pd.DataFrame({
    'Models':['Logistic Regression',
              'K-Nearest Neighbors',
              'Decision Tree',
              'Support Vector Machine',
              'Random Forest',
              'Gaussian Naive Bayes' ],
    'Accuracy':accu
                    })

# %%
results=results.sort_values(by='Accuracy',ascending=False)
print(results)
# Out:
#                    Models    Accuracy
# 1     K-Nearest Neighbors  100.000000
# 0     Logistic Regression   97.777778
# 3  Support Vector Machine   97.777778
# 4           Random Forest   97.777778
# 5    Gaussian Naive Bayes   97.777778
# 2           Decision Tree   95.555556
